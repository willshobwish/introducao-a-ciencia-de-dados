# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
from sklearn.preprocessing import LabelEncoder, StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'datasets\Diabetes prediction dataset.csv')

# %%
display(df)
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
les = LabelEncoder()
leg = LabelEncoder()

# %%
dfa = df
dfa['smoking_history'] = les.fit_transform(df['smoking_history'])
dfa['gender'] = les.fit_transform(df['gender'])

# %%
display(dfa)
# Out:
#        gender   age  hypertension  heart_disease  smoking_history    bmi  \
# 0           0  80.0             0              1                4  25.19
# 1           0  54.0             0              0                0  27.32
# 2           1  28.0             0              0                4  27.32
# 3           0  36.0             0              0                1  23.45
# 4           1  76.0             1              1                1  20.14
# ...       ...   ...           ...            ...              ...    ...
# 99995       0  80.0             0              0                0  27.32
# 99996       0   2.0             0              0                0  17.37
# 99997       1  66.0             0              0                3  27.83
# 99998       0  24.0             0              0                4  35.42
# 99999       0  57.0             0              0                1  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# ...

# %%
scaler = StandardScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(dfa), columns=dfa.columns)

# %%
#scaler.feature_names_in_
scaler.mean_
# Out:
# array([4.14660000e-01, 4.18858560e+01, 7.48500000e-02, 3.94200000e-02,
#        2.17965000e+00, 2.73207671e+01, 5.52750700e+00, 1.38058060e+02,
#        8.50000000e-02])

# %%
display(df_scaled)
# Out:
#          gender       age  hypertension  heart_disease  smoking_history  \
# 0     -0.841047  1.692704     -0.284439       4.936379         0.963327
# 1     -0.841047  0.538006     -0.284439      -0.202578        -1.153468
# 2      1.187234 -0.616691     -0.284439      -0.202578         0.963327
# 3     -0.841047 -0.261399     -0.284439      -0.202578        -0.624269
# 4      1.187234  1.515058      3.515687       4.936379        -0.624269
# ...         ...       ...           ...            ...              ...
# 99995 -0.841047  1.692704     -0.284439      -0.202578        -1.153468
# 99996 -0.841047 -1.771388     -0.284439      -0.202578        -1.153468
# 99997  1.187234  1.070944     -0.284439      -0.202578         0.434128
# 99998 -0.841047 -0.794336     -0.284439      -0.202578         0.963327
# 99999 -0.841047  0.671241     -0.284439      -0.202578        -0.624269
#
#             bmi  HbA1c_level  blood_glucose_level  diabetes  Cluster
# ...

# %%
kmeans = KMeans(n_clusters=3, random_state=1234, n_init=10)
df_scaled['Cluster'] = kmeans.fit_predict(df_scaled)

# Add cluster labels to original data
df['Cluster'] = df_scaled['Cluster']

# %%
sns.pairplot(df, hue="Cluster", palette="viridis", diag_kind="kde")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 sns.pairplot(df, hue="Cluster", palette="viridis", diag_kind="kde")
#       2 plt.show()
#
# File c:\Users\willi\miniconda3\envs\icd\Lib\site-packages\seaborn\axisgrid.py:2163, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2161 if kind == "scatter":
#    2162     from .relational import scatterplot  # Avoid circular import
# -> 2163     plotter(scatterplot, **plot_kws)
#    2164 elif kind == "reg":
#    2165     from .regression import regplot  # Avoid circular import
#
# File c:\Users\willi\miniconda3\envs\icd\Lib\site-packages\seaborn\axisgrid.py:1427, in PairGrid.map_offdiag(self, func, **kwargs)
#    1425     self.map_lower(func, **kwargs)
#    1426     if not self._corner:
# ...
